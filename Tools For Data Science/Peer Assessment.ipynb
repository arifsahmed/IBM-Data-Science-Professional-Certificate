# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# Peer Graded Assignment

# %% [markdown]
# Welcome to my Jupyterlite Notebook! In this notebook, I will be showcasing my skills in using various data science tools. Throughout this course, I have learned how to work with Jupyterlite Notebook, one of the easiest tools to share publicly. I will be leveraging this tool to create my final project, which will be graded by my peers.
#
# In this notebook, you will find a list of data science languages, libraries, and tools that I have learned during this course. You will also find examples of arithmetic expressions and functions that I have created using Python.
#
# I hope you enjoy exploring my project!

# %% [markdown]
# Ex4:
#
#
# Python: a high-level programming language widely used in data science for its simplicity, readability, and versatility.
#
# R: a programming language and software environment for statistical computing and graphics, widely used in data analysis and visualization.
#
# SQL: a domain-specific language used to manage relational databases, widely used in data storage and retrieval.
#
# MATLAB: a programming language and numerical computing environment often used for data analysis and visualization, particularly in engineering and scientific research.

# %% [markdown]
# Ex5:
#
#
# Pandas: a Python library for data manipulation and analysis, widely used for handling and cleaning large datasets.
#
# NumPy: a Python library for scientific computing, providing support for arrays and matrices, mathematical functions, and statistical analysis.
#
# Matplotlib: a Python library for creating visualizations and charts, widely used for data exploration and presentation.
#
# Scikit-learn: a Python library for machine learning, providing tools for classification, regression, clustering, and dimensionality reduction.
#
# TensorFlow: an open-source software library for dataflow and differentiable programming across a range of tasks, widely used for machine learning and deep learning applications.

# %% [markdown]
# ## Data Science Tools
#
# | Tool | Purpose | Description |
# | --- | --- | --- |
# | Jupyterlite Notebook | Data Science Environment | A web-based interactive computing environment that allows users to create and share documents that contain live code, equations, visualizations, and narrative text. |
# | Tableau | Data Visualization | A business intelligence and analytics software that helps people see and understand their data. Allows users to create interactive dashboards, charts, and graphs. |
# | Apache Hadoop | Data Storage and Processing | An open-source software framework that allows for distributed storage and processing of large datasets across clusters of computers. |
# | Apache Spark | Data Processing | An open-source distributed computing system used for large-scale data processing, machine learning, and graph processing. |
# | GitHub | Version Control and Collaboration | A web-based platform for version control and collaboration that allows users to host and review code, manage projects, and build software together. |

# %% [markdown]
# In this section, I will be showcasing some examples of arithmetic expressions using Python. Arithmetic expressions are mathematical calculations that involve numbers and operators, such as addition, subtraction, multiplication, and division. Through these examples, I will demonstrate how to perform basic arithmetic operations using Python code.
#
# I hope these examples will help you gain a better understanding of arithmetic expressions and how they can be used in data science applications.

# %%
# Multiplication and Addition Operations
# Declare variables
a = 5
b = 10
c = 2

# Multiply variables
result1 = a * b * c

# Add variables
result2 = a + b + c

# Print results
print("Result of multiplication:", result1)
print("Result of addition:", result2)
# Out:
# Running cells with 'c:\Users\Arif Ahmed\AppData\Local\Programs\Python\Python38-32\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Arif Ahmed/AppData/Local/Programs/Python/Python38-32/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %%
# Convert Minutes to Hours
# Declare variable
minutes = 120

# Convert minutes to hours
hours = minutes / 60

# Print result
print("120 minutes is equal to", hours, "hours.")
# Out:
# Running cells with 'c:\Users\Arif Ahmed\AppData\Local\Programs\Python\Python38-32\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Arif Ahmed/AppData/Local/Programs/Python/Python38-32/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# Objectives
# The objectives of this notebook are:
#
# To demonstrate my understanding of various data science tools, languages, and libraries learned during this course.
# To showcase my ability to perform basic arithmetic operations and write functions in Python.
# To provide examples of data visualization and analysis using various tools and libraries.
# To share my project with others in a clear and understandable way.
# I hope to achieve these objectives through this notebook and provide useful insights to the reader.

# %% [markdown]
# This notebook was created by Arif Ahmed. I hope you find this project informative and insightful. If you have any questions or feedback, please feel free to reach out to me. Thank you for taking the time to review my work!
